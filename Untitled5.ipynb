# %%
# !wget 'https://images.thedirect.com/media/article_full/superman-logo.jpg'
# Out:
# --2025-06-05 06:52:53--  https://images.thedirect.com/media/article_full/superman-logo.jpg
# Resolving images.thedirect.com (images.thedirect.com)... 50.18.233.228, 52.53.65.25
# Connecting to images.thedirect.com (images.thedirect.com)|50.18.233.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138129 (135K) [image/jpeg]
# Saving to: ‘superman-logo.jpg’
#
# superman-logo.jpg   100%[===================>] 134.89K  --.-KB/s    in 0.08s
#
# 2025-06-05 06:52:54 (1.75 MB/s) - ‘superman-logo.jpg’ saved [138129/138129]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/superman-logo.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
print(img)
# Out:
# [[[  3  28  82]
#   [  3  29  80]
#   [  1  29  79]
#   ...
#   [  3  39 135]
#   [  3  39 135]
#   [  3  39 135]]
#
#  [[  3  28  82]
#   [  3  29  80]
#   [  2  28  77]
#   ...
#   [  3  39 135]
#   [  3  39 135]
#   [  3  39 135]]
#
#  [[  5  28  80]
#   [  3  29  80]
#   [  2  28  77]
#   ...
#   [  3  39 135]
#   [  3  39 135]
#   [  3  39 135]]
#
#  ...
#
#  [[  7  48 100]
#   [  7  50 101]
#   [  7  53 105]
#   ...
#   [  1  29  76]
#   [  2  29  76]
#   [  2  29  76]]
#
#  [[  8  49 101]
#   [  8  51 102]
#   [  7  54 106]
#   ...
#   [  5  39  85]
#   [  5  37  84]
#   [  5  37  84]]
#
#  [[  9  50 102]
#   [  9  52 103]
#   [  7  54 106]
#   ...
#   [  0  37  82]
#   [  0  36  81]
#   [  0  35  80]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img=Image.open('/content/superman-logo.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('super_resized.jpg')

# %%
img_res=mpimg.imread('/content/super_resized.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img=cv2.imread('/content/superman-logo.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (720, 1280)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1280x720>
